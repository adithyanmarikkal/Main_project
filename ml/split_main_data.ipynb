# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import os

print("--- Part 1: Splitting the Main Dataset (Memory-Efficient & Safe) ---")

# --- Configuration with your specific paths ---
BASE_DIR = r"D:\FedShield,Personal\wataiData\csv\CICIoT2023"
FULL_DATASET_PATH = os.path.join(BASE_DIR, 'full_dataset.csv')
OUTPUT_DIR = os.path.join(BASE_DIR, 'federated_data')

# --- Other Configuration ---
SERVER_DATASET_SIZE = 0.10  # 10% for the initial global model
CHUNK_SIZE = 100000         # Process 100,000 rows at a time

# --- Create Output Directory ---
if not os.path.exists(OUTPUT_DIR):
    os.makedirs(OUTPUT_DIR)
    print(f"Created directory: {OUTPUT_DIR}")

# --- Define Output File Paths ---
server_output_path = os.path.join(OUTPUT_DIR, 'server_df.csv')
clients_output_path = os.path.join(OUTPUT_DIR, 'clients_df.csv')

# --- Remove old files if they exist ---
if os.path.exists(server_output_path):
    os.remove(server_output_path)
if os.path.exists(clients_output_path):
    os.remove(clients_output_path)

# --- Process the large CSV in chunks ---
print(f"Loading and processing {FULL_DATASET_PATH} in chunks...")
header_written = False
chunk_num = 1
reader = pd.read_csv(FULL_DATASET_PATH, chunksize=CHUNK_SIZE)

for chunk in reader:
    print(f"  -> Processing chunk {chunk_num}...")
    chunk.dropna(inplace=True)

    if chunk.empty:
        chunk_num += 1
        continue
    
    # *** START OF THE FIX ***
    # Check the counts of each label in the current chunk
    label_counts = chunk['label'].value_counts()
    
    # If any label has fewer than 2 samples, stratification is not possible
    if (label_counts < 2).any():
        print(f"     ! Chunk {chunk_num} has a rare label with only 1 sample. Assigning full chunk to clients_df to avoid error.")
        # In this rare case, we can't split, so we'll just append the whole chunk to the larger clients file
        if not header_written:
             clients_chunk.to_csv(clients_output_path, index=False, mode='w', header=True)
             # We still need a header for the server file, so we write an empty dataframe with the correct columns
             pd.DataFrame(columns=chunk.columns).to_csv(server_output_path, index=False, mode='w', header=True)
             header_written = True
        else:
             chunk.to_csv(clients_output_path, index=False, mode='a', header=False)
        
        chunk_num += 1
        continue # Skip to the next chunk
    # *** END OF THE FIX ***

    # If the check passes, split the chunk as normal
    server_chunk, clients_chunk = train_test_split(
        chunk,
        test_size=(1 - SERVER_DATASET_SIZE),
        random_state=42,
        stratify=chunk['label']
    )

    if not header_written:
        server_chunk.to_csv(server_output_path, index=False, mode='w', header=True)
        clients_chunk.to_csv(clients_output_path, index=False, mode='w', header=True)
        header_written = True
    else:
        server_chunk.to_csv(server_output_path, index=False, mode='a', header=False)
        clients_chunk.to_csv(clients_output_path, index=False, mode='a', header=False)
    
    chunk_num += 1

print(f"\n✅ Part 1 Complete!")
print(f"Data has been split and saved chunk by chunk.")
print(f"Initial server data saved to: {server_output_path}")
print(f"Combined client data saved to: {clients_output_path}")
# Out:
# --- Part 1: Splitting the Main Dataset (Memory-Efficient & Safe) ---
# Loading and processing D:\FedShield,Personal\wataiData\csv\CICIoT2023\full_dataset.csv in chunks...
#   -> Processing chunk 1...
#   -> Processing chunk 2...
#   -> Processing chunk 3...
#   -> Processing chunk 4...
#   -> Processing chunk 5...
#   -> Processing chunk 6...
#      ! Chunk 6 has a rare label with only 1 sample. Assigning full chunk to clients_df to avoid error.
#   -> Processing chunk 7...
#      ! Chunk 7 has a rare label with only 1 sample. Assigning full chunk to clients_df to avoid error.
#   -> Processing chunk 8...
#      ! Chunk 8 has a rare label with only 1 sample. Assigning full chunk to clients_df to avoid error.
#   -> Processing chunk 9...
#      ! Chunk 9 has a rare label with only 1 sample. Assigning full chunk to clients_df to avoid error.
#   -> Processing chunk 10...
#   -> Processing chunk 11...
#   -> Processing chunk 12...
#   -> Processing chunk 13...
#   -> Processing chunk 14...
#   -> Processing chunk 15...
#   -> Processing chunk 16...
#   -> Processing chunk 17...
#   -> Processing chunk 18...
#   -> Processing chunk 19...
#   -> Processing chunk 20...
#   -> Processing chunk 21...
#   -> Processing chunk 22...
#      ! Chunk 22 has a rare label with only 1 sample. Assigning full chunk to clients_df to avoid error.
#   -> Processing chunk 23...
#   -> Processing chunk 24...
#   -> Processing chunk 25...
#   -> Processing chunk 26...
#   -> Processing chunk 27...
#   -> Processing chunk 28...
#   -> Processing chunk 29...
#      ! Chunk 29 has a rare label with only 1 sample. Assigning full chunk to clients_df to avoid error.
#   -> Processing chunk 30...
#      ! Chunk 30 has a rare label with only 1 sample. Assigning full chunk to clients_df to avoid error.
#   -> Processing chunk 31...
#      ! Chunk 31 has a rare label with only 1 sample. Assigning full chunk to clients_df to avoid error.
#   -> Processing chunk 32...
#   -> Processing chunk 33...
#   -> Processing chunk 34...
#      ! Chunk 34 has a rare label with only 1 sample. Assigning full chunk to clients_df to avoid error.
#   -> Processing chunk 35...
#   -> Processing chunk 36...
#   -> Processing chunk 37...
#   -> Processing chunk 38...
#   -> Processing chunk 39...
#   -> Processing chunk 40...
#   -> Processing chunk 41...
#   -> Processing chunk 42...
#      ! Chunk 42 has a rare label with only 1 sample. Assigning full chunk to clients_df to avoid error.
#   -> Processing chunk 43...
#   -> Processing chunk 44...
#   -> Processing chunk 45...
#   -> Processing chunk 46...
#   -> Processing chunk 47...
#   -> Processing chunk 48...
#   -> Processing chunk 49...
#   -> Processing chunk 50...
#   -> Processing chunk 51...
#   -> Processing chunk 52...
#   -> Processing chunk 53...
#   -> Processing chunk 54...
#      ! Chunk 54 has a rare label with only 1 sample. Assigning full chunk to clients_df to avoid error.
#   -> Processing chunk 55...
#      ! Chunk 55 has a rare label with only 1 sample. Assigning full chunk to clients_df to avoid error.
#   -> Processing chunk 56...
#   -> Processing chunk 57...
#   -> Processing chunk 58...
#   -> Processing chunk 59...
#   -> Processing chunk 60...
#   -> Processing chunk 61...
#   -> Processing chunk 62...
#   -> Processing chunk 63...
#   -> Processing chunk 64...
#   -> Processing chunk 65...
#   -> Processing chunk 66...
#      ! Chunk 66 has a rare label with only 1 sample. Assigning full chunk to clients_df to avoid error.
#   -> Processing chunk 67...
#   -> Processing chunk 68...
#   -> Processing chunk 69...
#      ! Chunk 69 has a rare label with only 1 sample. Assigning full chunk to clients_df to avoid error.
#   -> Processing chunk 70...
#   -> Processing chunk 71...
#      ! Chunk 71 has a rare label with only 1 sample. Assigning full chunk to clients_df to avoid error.
#   -> Processing chunk 72...
#   -> Processing chunk 73...
#   -> Processing chunk 74...
#      ! Chunk 74 has a rare label with only 1 sample. Assigning full chunk to clients_df to avoid error.
#   -> Processing chunk 75...
#   -> Processing chunk 76...
#   -> Processing chunk 77...
#   -> Processing chunk 78...
#      ! Chunk 78 has a rare label with only 1 sample. Assigning full chunk to clients_df to avoid error.
#   -> Processing chunk 79...
#      ! Chunk 79 has a rare label with only 1 sample. Assigning full chunk to clients_df to avoid error.
#   -> Processing chunk 80...
#   -> Processing chunk 81...
#   -> Processing chunk 82...
#      ! Chunk 82 has a rare label with only 1 sample. Assigning full chunk to clients_df to avoid error.
#   -> Processing chunk 83...
#   -> Processing chunk 84...
#   -> Processing chunk 85...
#   -> Processing chunk 86...
#      ! Chunk 86 has a rare label with only 1 sample. Assigning full chunk to clients_df to avoid error.
#   -> Processing chunk 87...
#   -> Processing chunk 88...
#   -> Processing chunk 89...
#   -> Processing chunk 90...
#   -> Processing chunk 91...
#      ! Chunk 91 has a rare label with only 1 sample. Assigning full chunk to clients_df to avoid error.
#   -> Processing chunk 92...
#   -> Processing chunk 93...
#   -> Processing chunk 94...
#   -> Processing chunk 95...
#   -> Processing chunk 96...
#   -> Processing chunk 97...
#   -> Processing chunk 98...
#   -> Processing chunk 99...
#   -> Processing chunk 100...
#      ! Chunk 100 has a rare label with only 1 sample. Assigning full chunk to clients_df to avoid error.
#   -> Processing chunk 101...
#   -> Processing chunk 102...
#      ! Chunk 102 has a rare label with only 1 sample. Assigning full chunk to clients_df to avoid error.
#   -> Processing chunk 103...
#   -> Processing chunk 104...
#   -> Processing chunk 105...
#   -> Processing chunk 106...
#   -> Processing chunk 107...
#      ! Chunk 107 has a rare label with only 1 sample. Assigning full chunk to clients_df to avoid error.
#   -> Processing chunk 108...
#   -> Processing chunk 109...
#      ! Chunk 109 has a rare label with only 1 sample. Assigning full chunk to clients_df to avoid error.
#   -> Processing chunk 110...
#   -> Processing chunk 111...
#   -> Processing chunk 112...
#   -> Processing chunk 113...
#   -> Processing chunk 114...
#   -> Processing chunk 115...
#   -> Processing chunk 116...
#   -> Processing chunk 117...
#      ! Chunk 117 has a rare label with only 1 sample. Assigning full chunk to clients_df to avoid error.
#   -> Processing chunk 118...
#   -> Processing chunk 119...
#   -> Processing chunk 120...
#   -> Processing chunk 121...
#   -> Processing chunk 122...
#      ! Chunk 122 has a rare label with only 1 sample. Assigning full chunk to clients_df to avoid error.
#   -> Processing chunk 123...
#   -> Processing chunk 124...
#      ! Chunk 124 has a rare label with only 1 sample. Assigning full chunk to clients_df to avoid error.
#   -> Processing chunk 125...
#   -> Processing chunk 126...
#   -> Processing chunk 127...
#   -> Processing chunk 128...
#      ! Chunk 128 has a rare label with only 1 sample. Assigning full chunk to clients_df to avoid error.
#   -> Processing chunk 129...
#   -> Processing chunk 130...
#   -> Processing chunk 131...
#   -> Processing chunk 132...
#      ! Chunk 132 has a rare label with only 1 sample. Assigning full chunk to clients_df to avoid error.
#   -> Processing chunk 133...
#   -> Processing chunk 134...
#   -> Processing chunk 135...
#   -> Processing chunk 136...
#   -> Processing chunk 137...
#   -> Processing chunk 138...
#   -> Processing chunk 139...
#   -> Processing chunk 140...
#   -> Processing chunk 141...
#   -> Processing chunk 142...
#   -> Processing chunk 143...
#   -> Processing chunk 144...
#   -> Processing chunk 145...
#   -> Processing chunk 146...
#   -> Processing chunk 147...
#      ! Chunk 147 has a rare label with only 1 sample. Assigning full chunk to clients_df to avoid error.
#   -> Processing chunk 148...
#   -> Processing chunk 149...
#   -> Processing chunk 150...
#   -> Processing chunk 151...
#      ! Chunk 151 has a rare label with only 1 sample. Assigning full chunk to clients_df to avoid error.
#   -> Processing chunk 152...
#   -> Processing chunk 153...
#   -> Processing chunk 154...
#   -> Processing chunk 155...
#   -> Processing chunk 156...
#      ! Chunk 156 has a rare label with only 1 sample. Assigning full chunk to clients_df to avoid error.
#   -> Processing chunk 157...
#   -> Processing chunk 158...
#      ! Chunk 158 has a rare label with only 1 sample. Assigning full chunk to clients_df to avoid error.
#   -> Processing chunk 159...
#      ! Chunk 159 has a rare label with only 1 sample. Assigning full chunk to clients_df to avoid error.
#   -> Processing chunk 160...
#   -> Processing chunk 161...
#   -> Processing chunk 162...
#   -> Processing chunk 163...
#   -> Processing chunk 164...
#      ! Chunk 164 has a rare label with only 1 sample. Assigning full chunk to clients_df to avoid error.
#   -> Processing chunk 165...
#   -> Processing chunk 166...
#   -> Processing chunk 167...
#   -> Processing chunk 168...
#   -> Processing chunk 169...
#      ! Chunk 169 has a rare label with only 1 sample. Assigning full chunk to clients_df to avoid error.
#   -> Processing chunk 170...
#   -> Processing chunk 171...
#   -> Processing chunk 172...
#   -> Processing chunk 173...
#   -> Processing chunk 174...
#      ! Chunk 174 has a rare label with only 1 sample. Assigning full chunk to clients_df to avoid error.
#   -> Processing chunk 175...
#   -> Processing chunk 176...
#      ! Chunk 176 has a rare label with only 1 sample. Assigning full chunk to clients_df to avoid error.
#   -> Processing chunk 177...
#   -> Processing chunk 178...
#   -> Processing chunk 179...
#   -> Processing chunk 180...
#   -> Processing chunk 181...
#      ! Chunk 181 has a rare label with only 1 sample. Assigning full chunk to clients_df to avoid error.
#   -> Processing chunk 182...
#   -> Processing chunk 183...
#   -> Processing chunk 184...
#   -> Processing chunk 185...
#   -> Processing chunk 186...
#   -> Processing chunk 187...
#      ! Chunk 187 has a rare label with only 1 sample. Assigning full chunk to clients_df to avoid error.
#   -> Processing chunk 188...
#   -> Processing chunk 189...
#   -> Processing chunk 190...
#   -> Processing chunk 191...
#   -> Processing chunk 192...
#   -> Processing chunk 193...
#   -> Processing chunk 194...
#   -> Processing chunk 195...
#   -> Processing chunk 196...
#      ! Chunk 196 has a rare label with only 1 sample. Assigning full chunk to clients_df to avoid error.
#   -> Processing chunk 197...
#   -> Processing chunk 198...
#   -> Processing chunk 199...
#   -> Processing chunk 200...
#   -> Processing chunk 201...
#   -> Processing chunk 202...
#   -> Processing chunk 203...
#      ! Chunk 203 has a rare label with only 1 sample. Assigning full chunk to clients_df to avoid error.
#   -> Processing chunk 204...
#      ! Chunk 204 has a rare label with only 1 sample. Assigning full chunk to clients_df to avoid error.
#   -> Processing chunk 205...
#      ! Chunk 205 has a rare label with only 1 sample. Assigning full chunk to clients_df to avoid error.
#   -> Processing chunk 206...
#   -> Processing chunk 207...
#   -> Processing chunk 208...
#   -> Processing chunk 209...
#   -> Processing chunk 210...
#   -> Processing chunk 211...
#      ! Chunk 211 has a rare label with only 1 sample. Assigning full chunk to clients_df to avoid error.
#   -> Processing chunk 212...
#   -> Processing chunk 213...
#   -> Processing chunk 214...
#   -> Processing chunk 215...
#      ! Chunk 215 has a rare label with only 1 sample. Assigning full chunk to clients_df to avoid error.
#   -> Processing chunk 216...
#   -> Processing chunk 217...
#   -> Processing chunk 218...
#   -> Processing chunk 219...
#   -> Processing chunk 220...
#   -> Processing chunk 221...
#   -> Processing chunk 222...
#   -> Processing chunk 223...
#   -> Processing chunk 224...
#      ! Chunk 224 has a rare label with only 1 sample. Assigning full chunk to clients_df to avoid error.
#   -> Processing chunk 225...
#   -> Processing chunk 226...
#      ! Chunk 226 has a rare label with only 1 sample. Assigning full chunk to clients_df to avoid error.
#   -> Processing chunk 227...
#   -> Processing chunk 228...
#      ! Chunk 228 has a rare label with only 1 sample. Assigning full chunk to clients_df to avoid error.
#   -> Processing chunk 229...
#   -> Processing chunk 230...
#   -> Processing chunk 231...
#   -> Processing chunk 232...
#   -> Processing chunk 233...
#   -> Processing chunk 234...
#   -> Processing chunk 235...
#   -> Processing chunk 236...
#   -> Processing chunk 237...
#   -> Processing chunk 238...
#   -> Processing chunk 239...
#      ! Chunk 239 has a rare label with only 1 sample. Assigning full chunk to clients_df to avoid error.
#   -> Processing chunk 240...
#   -> Processing chunk 241...
#   -> Processing chunk 242...
#   -> Processing chunk 243...
#   -> Processing chunk 244...
#      ! Chunk 244 has a rare label with only 1 sample. Assigning full chunk to clients_df to avoid error.
#   -> Processing chunk 245...
#   -> Processing chunk 246...
#   -> Processing chunk 247...
#      ! Chunk 247 has a rare label with only 1 sample. Assigning full chunk to clients_df to avoid error.
#   -> Processing chunk 248...
#   -> Processing chunk 249...
#   -> Processing chunk 250...
#   -> Processing chunk 251...
#   -> Processing chunk 252...
#   -> Processing chunk 253...
#   -> Processing chunk 254...
#   -> Processing chunk 255...
#   -> Processing chunk 256...
#   -> Processing chunk 257...
#   -> Processing chunk 258...
#   -> Processing chunk 259...
#   -> Processing chunk 260...
#   -> Processing chunk 261...
#   -> Processing chunk 262...
#   -> Processing chunk 263...
#   -> Processing chunk 264...
#   -> Processing chunk 265...
#      ! Chunk 265 has a rare label with only 1 sample. Assigning full chunk to clients_df to avoid error.
#   -> Processing chunk 266...
#      ! Chunk 266 has a rare label with only 1 sample. Assigning full chunk to clients_df to avoid error.
#   -> Processing chunk 267...
#      ! Chunk 267 has a rare label with only 1 sample. Assigning full chunk to clients_df to avoid error.
#   -> Processing chunk 268...
#   -> Processing chunk 269...
#   -> Processing chunk 270...
#   -> Processing chunk 271...
#   -> Processing chunk 272...
#   -> Processing chunk 273...
#   -> Processing chunk 274...
#   -> Processing chunk 275...
#   -> Processing chunk 276...
#      ! Chunk 276 has a rare label with only 1 sample. Assigning full chunk to clients_df to avoid error.
#   -> Processing chunk 277...
#      ! Chunk 277 has a rare label with only 1 sample. Assigning full chunk to clients_df to avoid error.
#   -> Processing chunk 278...
#   -> Processing chunk 279...
#   -> Processing chunk 280...
#      ! Chunk 280 has a rare label with only 1 sample. Assigning full chunk to clients_df to avoid error.
#   -> Processing chunk 281...
#   -> Processing chunk 282...
#   -> Processing chunk 283...
#      ! Chunk 283 has a rare label with only 1 sample. Assigning full chunk to clients_df to avoid error.
#   -> Processing chunk 284...
#   -> Processing chunk 285...
#      ! Chunk 285 has a rare label with only 1 sample. Assigning full chunk to clients_df to avoid error.
#   -> Processing chunk 286...
#   -> Processing chunk 287...
#   -> Processing chunk 288...
#   -> Processing chunk 289...
#   -> Processing chunk 290...
#   -> Processing chunk 291...
#   -> Processing chunk 292...
#      ! Chunk 292 has a rare label with only 1 sample. Assigning full chunk to clients_df to avoid error.
#   -> Processing chunk 293...
#   -> Processing chunk 294...
#   -> Processing chunk 295...
#   -> Processing chunk 296...
#      ! Chunk 296 has a rare label with only 1 sample. Assigning full chunk to clients_df to avoid error.
#   -> Processing chunk 297...
#   -> Processing chunk 298...
#      ! Chunk 298 has a rare label with only 1 sample. Assigning full chunk to clients_df to avoid error.
#   -> Processing chunk 299...
#   -> Processing chunk 300...
#   -> Processing chunk 301...
#      ! Chunk 301 has a rare label with only 1 sample. Assigning full chunk to clients_df to avoid error.
#   -> Processing chunk 302...
#      ! Chunk 302 has a rare label with only 1 sample. Assigning full chunk to clients_df to avoid error.
#   -> Processing chunk 303...
#      ! Chunk 303 has a rare label with only 1 sample. Assigning full chunk to clients_df to avoid error.
#   -> Processing chunk 304...
#   -> Processing chunk 305...
#   -> Processing chunk 306...
#   -> Processing chunk 307...
#   -> Processing chunk 308...
#   -> Processing chunk 309...
#   -> Processing chunk 310...
#   -> Processing chunk 311...
#   -> Processing chunk 312...
#   -> Processing chunk 313...
#      ! Chunk 313 has a rare label with only 1 sample. Assigning full chunk to clients_df to avoid error.
#   -> Processing chunk 314...
#   -> Processing chunk 315...
#   -> Processing chunk 316...
#   -> Processing chunk 317...
#      ! Chunk 317 has a rare label with only 1 sample. Assigning full chunk to clients_df to avoid error.
#   -> Processing chunk 318...
#   -> Processing chunk 319...
#   -> Processing chunk 320...
#   -> Processing chunk 321...
#   -> Processing chunk 322...
#   -> Processing chunk 323...
#   -> Processing chunk 324...
#   -> Processing chunk 325...
#      ! Chunk 325 has a rare label with only 1 sample. Assigning full chunk to clients_df to avoid error.
#   -> Processing chunk 326...
#   -> Processing chunk 327...
#   -> Processing chunk 328...
#      ! Chunk 328 has a rare label with only 1 sample. Assigning full chunk to clients_df to avoid error.
#   -> Processing chunk 329...
#   -> Processing chunk 330...
#   -> Processing chunk 331...
#   -> Processing chunk 332...
#   -> Processing chunk 333...
#   -> Processing chunk 334...
#   -> Processing chunk 335...
#   -> Processing chunk 336...
#   -> Processing chunk 337...
#   -> Processing chunk 338...
#   -> Processing chunk 339...
#   -> Processing chunk 340...
#   -> Processing chunk 341...
#   -> Processing chunk 342...
#   -> Processing chunk 343...
#      ! Chunk 343 has a rare label with only 1 sample. Assigning full chunk to clients_df to avoid error.
#   -> Processing chunk 344...
#   -> Processing chunk 345...
#   -> Processing chunk 346...
#      ! Chunk 346 has a rare label with only 1 sample. Assigning full chunk to clients_df to avoid error.
#   -> Processing chunk 347...
#      ! Chunk 347 has a rare label with only 1 sample. Assigning full chunk to clients_df to avoid error.
#   -> Processing chunk 348...
#      ! Chunk 348 has a rare label with only 1 sample. Assigning full chunk to clients_df to avoid error.
#   -> Processing chunk 349...
#      ! Chunk 349 has a rare label with only 1 sample. Assigning full chunk to clients_df to avoid error.
#   -> Processing chunk 350...
#   -> Processing chunk 351...
#   -> Processing chunk 352...
#   -> Processing chunk 353...
#   -> Processing chunk 354...
#   -> Processing chunk 355...
#   -> Processing chunk 356...
#   -> Processing chunk 357...
#   -> Processing chunk 358...
#      ! Chunk 358 has a rare label with only 1 sample. Assigning full chunk to clients_df to avoid error.
#   -> Processing chunk 359...
#      ! Chunk 359 has a rare label with only 1 sample. Assigning full chunk to clients_df to avoid error.
#   -> Processing chunk 360...
#   -> Processing chunk 361...
#   -> Processing chunk 362...
#   -> Processing chunk 363...
#      ! Chunk 363 has a rare label with only 1 sample. Assigning full chunk to clients_df to avoid error.
#   -> Processing chunk 364...
#   -> Processing chunk 365...
#   -> Processing chunk 366...
#   -> Processing chunk 367...
#      ! Chunk 367 has a rare label with only 1 sample. Assigning full chunk to clients_df to avoid error.
#   -> Processing chunk 368...
#   -> Processing chunk 369...
#   -> Processing chunk 370...
#   -> Processing chunk 371...
#      ! Chunk 371 has a rare label with only 1 sample. Assigning full chunk to clients_df to avoid error.
#   -> Processing chunk 372...
#   -> Processing chunk 373...
#   -> Processing chunk 374...
#   -> Processing chunk 375...
#   -> Processing chunk 376...
#   -> Processing chunk 377...
#      ! Chunk 377 has a rare label with only 1 sample. Assigning full chunk to clients_df to avoid error.
#   -> Processing chunk 378...
#   -> Processing chunk 379...
#   -> Processing chunk 380...
#   -> Processing chunk 381...
#   -> Processing chunk 382...
#   -> Processing chunk 383...
#      ! Chunk 383 has a rare label with only 1 sample. Assigning full chunk to clients_df to avoid error.
#   -> Processing chunk 384...
#   -> Processing chunk 385...
#   -> Processing chunk 386...
#      ! Chunk 386 has a rare label with only 1 sample. Assigning full chunk to clients_df to avoid error.
#   -> Processing chunk 387...
#   -> Processing chunk 388...
#   -> Processing chunk 389...
#   -> Processing chunk 390...
#   -> Processing chunk 391...
#   -> Processing chunk 392...
#   -> Processing chunk 393...
#   -> Processing chunk 394...
#   -> Processing chunk 395...
#   -> Processing chunk 396...
#   -> Processing chunk 397...
#   -> Processing chunk 398...
#      ! Chunk 398 has a rare label with only 1 sample. Assigning full chunk to clients_df to avoid error.
#   -> Processing chunk 399...
#   -> Processing chunk 400...
#   -> Processing chunk 401...
#   -> Processing chunk 402...
#      ! Chunk 402 has a rare label with only 1 sample. Assigning full chunk to clients_df to avoid error.
#   -> Processing chunk 403...
#   -> Processing chunk 404...
#      ! Chunk 404 has a rare label with only 1 sample. Assigning full chunk to clients_df to avoid error.
#   -> Processing chunk 405...
#   -> Processing chunk 406...
#   -> Processing chunk 407...
#   -> Processing chunk 408...
#   -> Processing chunk 409...
#   -> Processing chunk 410...
#   -> Processing chunk 411...
#      ! Chunk 411 has a rare label with only 1 sample. Assigning full chunk to clients_df to avoid error.
#   -> Processing chunk 412...
#   -> Processing chunk 413...
#   -> Processing chunk 414...
#   -> Processing chunk 415...
#   -> Processing chunk 416...
#   -> Processing chunk 417...
#   -> Processing chunk 418...
#   -> Processing chunk 419...
#   -> Processing chunk 420...
#   -> Processing chunk 421...
#   -> Processing chunk 422...
#      ! Chunk 422 has a rare label with only 1 sample. Assigning full chunk to clients_df to avoid error.
#   -> Processing chunk 423...
#   -> Processing chunk 424...
#   -> Processing chunk 425...
#   -> Processing chunk 426...
#   -> Processing chunk 427...
#   -> Processing chunk 428...
#   -> Processing chunk 429...
#   -> Processing chunk 430...
#   -> Processing chunk 431...
#   -> Processing chunk 432...
#   -> Processing chunk 433...
#   -> Processing chunk 434...
#   -> Processing chunk 435...
#      ! Chunk 435 has a rare label with only 1 sample. Assigning full chunk to clients_df to avoid error.
#   -> Processing chunk 436...
#      ! Chunk 436 has a rare label with only 1 sample. Assigning full chunk to clients_df to avoid error.
#   -> Processing chunk 437...
#   -> Processing chunk 438...
#   -> Processing chunk 439...
#   -> Processing chunk 440...
#      ! Chunk 440 has a rare label with only 1 sample. Assigning full chunk to clients_df to avoid error.
#   -> Processing chunk 441...
#   -> Processing chunk 442...
#   -> Processing chunk 443...
#   -> Processing chunk 444...
#   -> Processing chunk 445...
#      ! Chunk 445 has a rare label with only 1 sample. Assigning full chunk to clients_df to avoid error.
#   -> Processing chunk 446...
#   -> Processing chunk 447...
#      ! Chunk 447 has a rare label with only 1 sample. Assigning full chunk to clients_df to avoid error.
#   -> Processing chunk 448...
#   -> Processing chunk 449...
#   -> Processing chunk 450...
#   -> Processing chunk 451...
#   -> Processing chunk 452...
#   -> Processing chunk 453...
#   -> Processing chunk 454...
#   -> Processing chunk 455...
#      ! Chunk 455 has a rare label with only 1 sample. Assigning full chunk to clients_df to avoid error.
#   -> Processing chunk 456...
#      ! Chunk 456 has a rare label with only 1 sample. Assigning full chunk to clients_df to avoid error.
#   -> Processing chunk 457...
#      ! Chunk 457 has a rare label with only 1 sample. Assigning full chunk to clients_df to avoid error.
#   -> Processing chunk 458...
#      ! Chunk 458 has a rare label with only 1 sample. Assigning full chunk to clients_df to avoid error.
#   -> Processing chunk 459...
#   -> Processing chunk 460...
#   -> Processing chunk 461...
#   -> Processing chunk 462...
#   -> Processing chunk 463...
#   -> Processing chunk 464...
#   -> Processing chunk 465...
#   -> Processing chunk 466...
#   -> Processing chunk 467...
#   -> Processing chunk 468...
#      ! Chunk 468 has a rare label with only 1 sample. Assigning full chunk to clients_df to avoid error.
#
# ✅ Part 1 Complete!
# Data has been split and saved chunk by chunk.
# Initial server data saved to: D:\FedShield,Personal\wataiData\csv\CICIoT2023\federated_data\server_df.csv
# Combined client data saved to: D:\FedShield,Personal\wataiData\csv\CICIoT2023\federated_data\clients_df.csv
